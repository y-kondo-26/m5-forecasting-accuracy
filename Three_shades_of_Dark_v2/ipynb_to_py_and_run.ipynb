# %%
# !ipython nbconvert --to python m5-simple-fe.ipynb
# !ipython nbconvert --to python m5-lags-features.ipynb
# !ipython nbconvert --to python m5-custom-features.ipynb
# !ipython nbconvert --to python m5-three-shades-of-dark-darker-magic_v2.ipynb
# Out:
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook m5-simple-fe.ipynb to python
# [NbConvertApp] Writing 13542 bytes to m5-simple-fe.py
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook m5-lags-features.ipynb to python
# [NbConvertApp] Writing 9685 bytes to m5-lags-features.py
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook m5-custom-features.ipynb to python
# ...

# %%
# !python3 m5-simple-fe.py
# Out:
# Load Main Data
# Create Grid
# Train rows: 30490 58327370
#     Original grid_df:   3.5GiB
#      Reduced grid_df:   1.3GiB
# Release week
#     Original grid_df:   1.7GiB
#      Reduced grid_df:   1.5GiB
# Save Part 1
# Size: (46881677, 10)
# Prices
# Merge prices and save part 2
# Mem. usage decreased to 1789.88 Mb (62.2% reduction)
# Size: (46881677, 13)
# Save part 3
# Size: (46881677, 16)
#            Full Grid:   2.4GiB
# Size: (46881677, 34)
#            Full Grid:   1.1GiB
#            Full Grid: 292.5MiB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4788267 entries, 0 to 46854235
# Data columns (total 34 columns):
# id                  category
# item_id             category
# dept_id             category
# cat_id              category
# store_id            category
# state_id            category
# d                   int16
# sales               float64
# release             int16
# sell_price          float16
# price_max           float16
# ...

# %%
# !python3 m5-lags-features.py
# Out:
# Load Main Data
# Shape (12196, 1919)
# Shifting: 1
# Shifting: 2
# Shifting: 3
# Shifting: 4
# Shifting: 5
# Shifting: 6
# Shifting: 7
# 1.40 min: Time for loops
# 1.32 min: Time for bulk shift
# Rolling period: 14
# Rolling period: 28
# Rolling period: 56
# 1.59 min: Time for loop
#  Original rolling df:   1.3GiB
#    Values rolling df:   1.0GiB
# Create lags
# 6.74 min: Lags
# Create rolling aggs
# Rolling period: 7
# Rolling period: 14
# Rolling period: 30
# Rolling period: 60
# Rolling period: 180
# Shifting period: 1
# Shifting period: 7
# Shifting period: 14
# Shifting period: 336
# 17.18 min: Lags
# Save lags and rollings
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46881677 entries, 0 to 46881676
# Data columns (total 44 columns):
# id                         category
# d                          int16
# sales                      float64
# sales_lag_28               float16
# sales_lag_29               float16
# sales_lag_30               float16
# ...

# %%
# !python3 m5-custom-features.py
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2960025 entries, 0 to 2960024
# Data columns (total 34 columns):
# id                  category
# item_id             category
# dept_id             category
# cat_id              category
# store_id            category
# state_id            category
# d                   int16
# sales               float64
# release             int16
# sell_price          float16
# price_max           float16
# price_min           float16
# price_std           float16
# price_mean          float16
# price_norm          float16
# price_nunique       float16
# item_nunique        int16
# price_momentum      float16
# price_momentum_m    float16
# price_momentum_y    float16
# event_name_1        category
# event_type_1        category
# event_name_2        category
# event_type_2        category
# snap_CA             category
# snap_TX             category
# snap_WI             category
# tm_d                int8
# tm_w                int8
# ...

# %%
# !python3 m5-three-shades-of-dark-darker-magic_v2.py
# Out:
# N_CORES=72
# Train CA_1
# [LightGBM] [Info] Saving data to binary file train_data.bin
# [100]	valid_0's rmse: 2.02104
# [200]	valid_0's rmse: 2.00183
# [300]	valid_0's rmse: 1.9924
# [400]	valid_0's rmse: 1.98545
# [500]	valid_0's rmse: 1.97846
# [600]	valid_0's rmse: 1.97312
# [700]	valid_0's rmse: 1.96754
# [800]	valid_0's rmse: 1.96268
# [900]	valid_0's rmse: 1.95733
# [1000]	valid_0's rmse: 1.95207
# [1100]	valid_0's rmse: 1.94733
# [1200]	valid_0's rmse: 1.9433
# [1300]	valid_0's rmse: 1.93869
# [1400]	valid_0's rmse: 1.93443
# Traceback (most recent call last):
#   File "m5-three-shades-of-dark-darker-magic_v2.py", line 423, in <module>
#     get_ipython().system('rm train_data.bin')
# NameError: name 'get_ipython' is not defined
